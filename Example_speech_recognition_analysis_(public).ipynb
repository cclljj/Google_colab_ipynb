# %% [markdown]
# <a href="https://colab.research.google.com/github/cclljj/Google_colab_ipynb/blob/master/Example_speech_recognition_analysis_(public).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   Olivia Tanuwidjaja (2022/2/12), Speech Recognition for Analytics (https://towardsdatascience.com/speech-recognition-for-analytics-e98c1e496873)
# *   https://github.com/oliviatan29/speech-recognition-analysis/blob/main/Speech%20Recognition.ipynb
#
# * How to iterate over an audio file in 20s intervals? (https://stackoverflow.com/questions/53540087/how-to-iterate-over-an-audio-file-in-20s-intervals)
#
# * Python | Speech recognition on large audio files (https://www.geeksforgeeks.org/python-speech-recognition-on-large-audio-files/)

# %%
# Import generic libraries
# !pip install pydub      # splitting audio files and stuff
# !pip install SpeechRecognition
# !pip install opencc-python-reimplemented
# !pip install pytube

import pandas as pd
import numpy as np
import sys
from google.colab import output
import matplotlib.pyplot as plt
from pydub.silence import split_on_silence


def aptget(cmd):
  tag='apt-get-{}'.format(cmd.replace(' ','-'))
  with output.use_tags(tag):
    print('Executing {} \n'.format(cmd))
    # !apt-get $cmd
    sys.stdout.flush()
        
  output.clear(output_tags=tag)
  print('Executing {} ... Done. (output hidden for tidyness)'.format(cmd))

aptget('update')
aptget('upgrade')
aptget('install ffmpeg')
aptget('install ffprobe')
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/dist-packages (0.25.1)
# Requirement already satisfied: SpeechRecognition in /usr/local/lib/python3.7/dist-packages (3.8.1)
# Requirement already satisfied: opencc-python-reimplemented in /usr/local/lib/python3.7/dist-packages (0.1.6)
# Requirement already satisfied: pytube in /usr/local/lib/python3.7/dist-packages (12.0.0)
# Executing update ... Done. (output hidden for tidyness)
# Executing upgrade ... Done. (output hidden for tidyness)
# Executing install ffmpeg ... Done. (output hidden for tidyness)
# Executing install ffprobe ... Done. (output hidden for tidyness)

# %%
# Import AudioSegment and play
from pydub import AudioSegment

AudioSegment.converter = "ffmpeg"
AudioSegment.ffmpeg = "ffmpeg"
AudioSegment.ffprobe ="ffprobe"

from pydub.playback import play

# %% [markdown]
# # Example 1: Speech recognition using YouTube video

# %%
import speech_recognition as sr
from pytube import YouTube
from opencc import OpenCC

youtube_URL = "https://www.youtube.com/watch?v=f7T9dVKzQ5c"
youtube_fname = 'tmp_youtube.mp4'
youtube_wav_fname = 'tmp_youtube.wav'

yt = YouTube(youtube_URL)
yt.streams.filter(only_audio=True)

# choose the audio stream itag
stream = yt.streams.get_by_itag(139)

stream.download(filename=youtube_fname)
# Out:
# '/content/tmp_youtube.mp4'

# %%
raw_file = AudioSegment.from_file(file=youtube_fname, format="mp4")

raw_file.export(out_f=youtube_wav_fname , format="wav")
wav_file = AudioSegment.from_file(file=youtube_wav_fname, format="wav")
wav_file_length = wav_file.duration_seconds

cc = OpenCC('s2twp')

# Set up recognizer
r = sr.Recognizer()
r.energy_threshold = 300

number_of_iterations = int(wav_file_length/20)
if number_of_iterations == 0:
  number_of_iterations = 1

test_audio = sr.AudioFile(youtube_wav_fname)
for i in range(number_of_iterations):
  with test_audio as source:
    audio = r.record(source, offset = i*20, duration = 20)

    google = r.recognize_google(audio, language = 'zh-TW' )
    print(cc.convert(google))
# Out:
# 從微信的空氣品質感測一直到智慧城市治理
# 我們如何知道空氣品質好不好我們早期的話我們可能就是會到環保署的這個官方資料有一個空氣品質監測網那我們全臺灣大概目前有將近80箇中標準測站這個張立80個標準測算呢它可以同時兩側幾種不同的汙染物那1我們現在所在地
# 華山園區來說的話還不可以直接拿離我最近的車站來代表我這個地方的空氣品質嗎顯然不行嗎更不用說我們旁邊有這個高架橋高架橋下可能這個交通流量很大帶來的這個交通染有很多所以這個你變得非常棘手到底現在這個地方空氣品質好不好
# 你們能不能夠去組裝一個微信的趕車去然後可以讓我帶著到處兩側設有就自己偷偷做看看但是這一座很就花了三年時間從無到有開始去收集市面上感測器開始去組裝開始去做量測試面上了非常非常多的氛圍顯感測器不是說任何一個這種微型的簡單的感受
# 原價買回來裝下就能動他就叫做是一個微型的空氣品質感測器絕對不是而是說這個空氣品質的感測器它必須要能夠跟標準的儀器它至少要有一定的趨勢的相關這個東西才是可用的感測器但是唯心感測器它雖然好像不是用的標準這個詞不是目的
# 高亮不知道準確可是為什麼它能夠用因為它有個很重要關鍵是它體積非常小它價錢非常便宜所以我們可以大量的部件我們可以用以量取勝我們必須要有非常多的感測器源源不絕提供我資料讓我可以去應用只有我們所希望達到目標是每個人都有一個感測器可以隨時
# 帶著但是我要如何去應Power每個人開車這件事情那我就必須要把所有的技術門檻給強的將來越低越好我們所用的元件全部都是開放的元件全部都是市面上買得到的軟體我們的所有的程式碼全部都在網路上你可以自由下載全部都是open source我們所熟
# 大的data全部都是Open data所以我們把技術門檻降的這麼低為了就是我們希望要能夠引力越來越多更多的人可以去參與我們這個生態系我記得2015年的時候我們剛開始發起這個活動我們組織的第1次的社群聚會那次來的100多個人這個社群這麼的
# 有興趣參與這樣一個參與式感受生態系與是乎開始遊廠商也進來廠商進來之後呢是地方政府也進來了那我可不可以利用這樣的一個感測器去表達我對於我曾是一頭居民的關心接著教育圈也拉了進來老師們發現說這個趕車去第1個
# 從無到有組裝過程原來可以這麼的簡單說他很適合拿來做創客教育其他老謝發所以這樣一個感受的工具這麼的便宜可以吸毒所以我可以帶著這個趕車去跟學生去做些環境教育接著中央政府也跳進來了中央政府在前瞻計劃裡頭
# 他也多了一筆錢在做全臺灣的校園附件最現在全臺灣每一個公民小學國民中學都有一條強的機器環孢素也跟著進來的最環保署接下也有一個機會城鄉的一個物聯網的計劃在全臺灣的工業區交通要道也要部件超過10000臺的這種微信
# 該捨棄那要去作捕捉這些排放源獲取瞭解我們的環境發生什麼事情啊各位可以想象每五分鐘就和筆桿車只要可以傳回來那每一臺機器上面都有時間都有GPS座標他就是一個完美的時空大資料沒有的這一些感測器
# 透過網路把資料傳進來之後我們可以有一些很基本的資料的一個統計但是一旦我們把它加入更高深的一些人工智慧去做更多的分析之後我們產生了第6次無限大這個是2017年1月30號有一個大陸的這個買還好從北到南擴散的過程浪費看到早上去
# 辦的時候這個買害就登陸奇隆王子報接著跳過這一角截去沒有感受氣好到臺中的時候大概是10點多我家的車往南走這是有史以來第1次我們利用為新感測器1000多臺來自全臺灣不同人這些甚至不認識他是誰
# 待大家同心協力把感測器裝前發資料送到同一個資料庫然後我們把資料彙集起來說做出了動畫有好多環境教會的知識那就從此就開始發生了我就是2017年2月4號這一天剛好是農曆初九天公生黑白提供航空發展模式
# 這是全臺中帶有300多臺機器晚上10點10一點12.1點兩點回去睡覺看到這個影片之後我們就可以開始想說我們是不是要一起去為環境做點事情
# 是我們今年是指色明年的不讓它紅色就好了我們慢慢的去改變它我們可以開始有些反思我們開始會去觀察人與環境之間的互動文會去想看看說自己的哪一些行為可能會改變環境於是我們有些社群的朋友他因為這件事情他就戒菸了那我
# 在這個這去年的話是四月23號高雄彌陀有一個塑膠袋廠大火就是這個濃濃的黑煙從高雄一路往北但如果我們這時候使用的是環保署的車佔用他不得比較稀疏所以你大概只有一可以看到說下午5點的時候這個煙雨好大概在高雄拿到了晚上9點的時候和他
# 調到臺南這個家一代但是如果我們使用微型感測器的話因為我們留捕捉到每五分鐘一筆的非常細緻的這種時空解析度的資料嗎因為我們在這個地方一樣有一兩百臺的感受其實我們可以捕捉到及時的現在汙染在哪裡我們可以去提高大家的警覺
# What's the next接下來可以做什麼我們要創新要應用嗎所以就說我我有了這個空間上密集的這個部件我會來集集小時的這個預測之後就開始去做一個最佳空瓶的導航你可以去找一條路線他是可以讓你洗澡
# 乾淨的空氣B未來來說的話我想我們還需要很多跨領域的合作和我想要需要各自幹不同的資料員當然我們需要更多人投入關注幫忙好拿著大家一起共創更好那也包含在座的各位謝謝大家

# %% [markdown]
# # Example 2: Speech recognition using online MP3 file
#
# 演講稿：109年 總統國慶演說：符合對等尊嚴 願促成兩岸有意義對話【全文】
# https://www.cna.com.tw/news/firstnews/202010105005.aspx

# %%
import speech_recognition as sr
from opencc import OpenCC

# %%
# !wget https://www.dropbox.com/s/18d9f8ao8yiwgr6/President_Tsai_Speech.mp3

mp3_fname = "President_Tsai_Speech.mp3"
wav_fname = "temp.wav"

# Create an AudioSegment instance
raw_file = AudioSegment.from_file(file=mp3_fname, format="mp3")

# Export the .mp3 file as wav
raw_file.export(out_f=wav_fname, format="wav")
wav_file = AudioSegment.from_file(file=wav_fname, format="wav")
# Out:
# --2022-02-16 08:36:46--  https://www.dropbox.com/s/18d9f8ao8yiwgr6/President_Tsai_Speech.mp3
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/18d9f8ao8yiwgr6/President_Tsai_Speech.mp3 [following]
# --2022-02-16 08:36:46--  https://www.dropbox.com/s/raw/18d9f8ao8yiwgr6/President_Tsai_Speech.mp3
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb1b582bf306c41aeaaed094fca.dl.dropboxusercontent.com/cd/0/inline/Bf3mjX254A5JKLKPP6KihRgrh0HUzrDvhSmU5L6FfqytJyFuaWbWoeNu1UB_8tEYhy-Ewr_zldikf-qXoWrfSoKAcWAbLoVJ4GFJUt3AyIm3mdu960OIc_rKpv52-GK9rq52TT3e1bWuCjFnXZDXW4Br/file# [following]
# --2022-02-16 08:36:46--  https://ucb1b582bf306c41aeaaed094fca.dl.dropboxusercontent.com/cd/0/inline/Bf3mjX254A5JKLKPP6KihRgrh0HUzrDvhSmU5L6FfqytJyFuaWbWoeNu1UB_8tEYhy-Ewr_zldikf-qXoWrfSoKAcWAbLoVJ4GFJUt3AyIm3mdu960OIc_rKpv52-GK9rq52TT3e1bWuCjFnXZDXW4Br/file
# Resolving ucb1b582bf306c41aeaaed094fca.dl.dropboxusercontent.com (ucb1b582bf306c41aeaaed094fca.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to ucb1b582bf306c41aeaaed094fca.dl.dropboxusercontent.com (ucb1b582bf306c41aeaaed094fca.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [audio/mpeg]
# Saving to: ‘President_Tsai_Speech.mp3.3’
#
# President_Tsai_Spee     [      <=>           ]  42.64M  38.5MB/s    in 1.1s
#
# 2022-02-16 08:36:48 (38.5 MB/s) - ‘President_Tsai_Speech.mp3.3’ saved [44713773]

# %%
wav_file_length = wav_file.duration_seconds
print("The speech file is " + str(wav_file_length) + " seconds long.")
number_of_iterations = int(wav_file_length/20)
if number_of_iterations == 0:
  number_of_iterations = 1

# Set up recognizer
r = sr.Recognizer()
r.energy_threshold = 300

cc = OpenCC('s2twp')
test_audio = sr.AudioFile("temp.wav")


for i in range(number_of_iterations):
  with test_audio as source:
    audio = r.record(source, offset = i*20, duration = 20)
    try:
      speech_text = r.recognize_google(audio, language = 'zh-TW' )
      print(cc.convert(speech_text))
    except:
      speech_text = ""
      pass
# Out:
# The speech file is 1397.2375625 seconds long.
# 大會主席遊戲坤院長現場各位貴賓電視機前還有網路上的全體國人同胞大家早安大家好
# 今天是中華民國109年的國慶日今年因為一起盡顯的規模縮小了但是所有的
# 無論身在何處都發自內心清和中華民國臺灣渡過了重重挑戰的一年2020年在新型冠狀病毒威脅下溫室
# 臺灣或者是全世界都是驚濤駭浪的一年但是也因為這場全球性的危機才讓國際社會看到臺灣漸認識到的特質還能來我們沒有風塵
# 沒有關閉學校也是世界上少數還能夠在管制措施下開打之棒舉辦大型一文活動的國家我們更展現的後人的玻璃將防疫物資送到
# 世界各地從今年3月以來有超過3300篇國際媒體報道都在談論臺灣的防疫表現臺灣在國際上的面貌越來越清晰
# 比過去任何時期都更加的兩眼這樣的成就要歸功於全體臺灣人民的團結合作除了最辛苦的醫護板檢疫人員我們要感謝
# 製造業吸收投入防疫物資生產科技業開發App要是朋友超商的員工協助傳送口罩還有我們所有的民眾井然有序的配合各項的防疫措施
# 我們也看到海外歸來的國人比規定居家隔離檢疫與行業者提供防疫旅館專車業者提供網易車隊餐廳娛樂場所落實實名制規定因為
# 全國上下一心我們守住的疫情的防線讓臺灣成為世界的模範生當日本的申請人手牽手相傑克的韋德棋差一著美國的阿扎爾部長坦克拉科夫斯基
# 相繼來訪表達他們對臺灣的敬意的時候相資訊許多多的國人都感到無比的真分數和語言的挑戰我們證明了國家在逆境中的生存能力建立了國米
# 自信更重要的是我們團結了因為我們深刻的體會到守護家園的重要所以這一年確實是一個辛苦而險峻的一年但也是豐收的一年今天的大會中邀請到
# 行各業的防疫英雄來過我們領唱國歌其中有很多我們熟悉的故事項是哪一年護理師臉上光榮的口罩牙和或者是張玩兒護理師
# 家人出任務陪伴血友病少年返臺的感人的事蹟還有更多的無名的英雄不曾被報道因為這一場戰役有太多人的投入有說不完的故事啊請現場的好
# 用最熱烈的掌聲再一次給我們的防疫英雄們滿滿的感謝謝謝他們為臺灣合作的最初因為
# 疫情控制得到臺灣成為全球少數可以維持經濟正成長的國家我們也會一行後的經濟發展超前部署六大核心戰略產業正在積極規劃推動前瞻基礎建
# 計劃也已經分析編列特別帥賈素進行當中最讓我們感到振奮的事是國人及其對臺灣經濟發展的信心更強的臺灣資本長期以來外流的趨勢已經反轉
# 我們迎來幾10年來最大規模的資金迴流潮牌商返臺投資已經超過新臺幣一照還有數以千億計的謝謝我們的臺商朋友還有數億
# 新一季的海外金資金正在陸續的會會許多外商跟知名的跨國企業也在加碼投資臺灣這些都是現在進行是在國際經貿合作的領域我們有不少
# 獅子的進展臺灣和美國將進行高層經濟對話在全球供應鏈重組科技合作基礎建設等領域尋求未來合作的空間上週臺美雙方宣佈已經完成簽署
# 臺北基礎建設融資及市場建立的合作架構雙方將攜手投入美洲以及印太地區的基礎建設計劃還沒經濟合作的深化已經進到行動的階段這也是我們在國際經貿合作上
# 尋求全面性突破的開始不過我也要提醒國人全球疫情還沒有結束一行帶給各國的經濟社會層面的複雜的挑戰仍然是很嚴峻長還未來我們還有更艱鉅的挑戰
# 我們去克服疫情後世界經濟的復原人類生活形態的轉變全球以及區域貿易與形式的劇烈的變化還有近期持續的重整每一項都考驗我們經濟的續航力以及整體的應變能力
# 面對數10年來最大的內外邊距臺灣會持續展現我們的任性政府會長何做炒三個策略方向前期打造大家所期待的新臺灣經濟
# 首先我們要全力全方位的投入供應鏈的重組現在全球供應鏈的快速結構更重組是一個不可逆轉的趨勢格的臺商也正朝向是個市場轉移生產基地回來投資等方向
# 加速調整我們已經在推動的獨家樂產業創新六大核心戰略產業照原投資計劃新南向政策還沒經濟合作參與區域經濟整合等等都含供應鏈重組及其相關
# 我們會將這些相關的政策跟計劃串聯起來並且整合政府的民間的資源以及跨部會的能量全力全方位的投入讓臺灣成為全球供應鏈不可或缺的關鍵力量第2
# 我們要達到臺灣成為國際資本人才及數位技術匯聚的種子未來供應鏈的重組最關鍵的元素是資本人才以及邁向數位經濟時代的核心技術我們將會在
# 進國際資本跟人才的環境及法治上持續的深化改革排除障礙同時也會通過國際交流產學合作以及雙語國家政策的努力積極培育國內的產業人才另外一方面我們也會
# 用臺灣仔仔通訊半導體物聯網人工智慧等優勢開發及掌握核心技術將是推動產業跟經濟的數位轉型的三我們要全力落實經濟與社會的均衡發展
# 疫情後的經濟產業的發展可能會有失衡的風險資金供給的大幅的增加也可能帶來後遺症所以未來政府會更加重視資源合理分配照顧因為經濟轉型和手衝
# 你的弱勢族群加強促進青年就業引導資金進入最有效的利用石臺灣經濟再起的紅利可以讓全國的人民在共享當然臺灣經濟的前景
# 是有賴於區域的和平穩定我們很清楚是弱退讓我會帶來和平只有次我準備充足憑藉著堅實的行為決心和實力才能保障臺灣的安全維護區域的和平
# 精進國防實力強的戰爭的風險這是當前我們的國防政策的原則這段時間面對對岸之間的騷擾臺海情勢雖然比較緊張但是我們的國君都能夠及時掌握
# 漢陰影打成皇為固守的任務在近年來只要我有時間我就會前往部隊看看我們的國軍官兵從高山上的空軍雷達站到返航靠港的海軍艦隊從在
# 問第1超人超鏈的火炮陸軍部隊到培養年輕軍事官的學校我的目的不僅是要對這些日夜輪班保家衛國的軍人說一聲謝謝也要但也要讓我們的國人知道國軍
# 是我們的家人也是國家主權是由民主最強的後盾在中國軍官兵互動
# 許多故事堅定了我的資訊我還記得當我定我到的一線空軍部隊的時候緊解釋理隨時準備緊急出行的非官充滿信心的告訴我不必講空房交給空軍
# 我也記得我在陸軍工訓中心看到我們女性軍官帶領的工兵同袍展現出逢山開路遇水架橋的氣魄在海軍水下作業答對得有穿在重灌備的弟兄姐妹
# 奮勇前入海底排除障礙這就是中華民國國軍他們部分前線後勤部分男女都是我們的子弟都有共同守護國家的信念這段時間以來也有國軍弟兄姐妹
# 執行任務的過程中為國受傷甚至訓子我們改變他們的付出並且已經用盡責的國軍偉榮升為三軍統帥國軍的未來未來的國君就是我最新新
# 今年的事情面對對岸的軍事擴張跟調戲我們會持續強化防衛戰力的現代化並且提升不對稱的戰力在外國武器裝備的同時我們仍然堅持加速推動國防自主
# 我到潛艦國造已經有相當的成效我們將以雙軌並進的方式來強化我們行為的實力不僅武器裝備效能正在提升我軍更需要有數值優秀的
# 除了棲身之緣從軍的關係並的專業素養更要建立有效的後備制度來強化國軍的人力數值以及戰力這段時間以來相信有許多被教育召集的後備軍人都覺得
# 嚼著變得更加的矜持了而在長虹一體的原則下接下來後被動員制度的改革將會快速的推動面對區域和平穩定受到威脅我們堅守不會再不求在的緣
# 避免擦槍走火廣釋出一個40的釋出共軍的動態海周邊的國家交換資訊強化安全和半形色也讓過人明瞭臺海動態讓全民國防更加的天使這段時間
# 我們都密切注意著去安全形勢的變動從南海東海主權爭議中印衝突到臺海局勢的變動乃至一個國關切的港版國安法的實施印太區域的民主和平與繁榮正受到
# 嚴峻的挑戰去那個國家為了確保自身的安全跟民主的體質不受到外在因素的影響而展開了各種形式的合縱連橫已經導致這個區域發生前所未有的情勢
# 電話我們要把電梯的是練轉變成歷史的機遇我們堅持主權以及守護民主價值的原則不會改變但在策略上也會保持彈性靈活應用
# 形式在改變只有超前部署才能掌握未來才不會在變局中隨波逐流甚至被別人決定了命令我們將積極參與未來的國際根區新秩序的建立我們會秉持價值
# 同門的原則在國際社會廣結善緣並且跟理念相近還有我的國家持續的提升夥伴的關係我們也會更積極的參與區域及國際的多邊合作反對華為10和平促進
# 能發展這就是中華民國臺灣在區域中最重要的價值我們要做梁山的力量的參與者將進步跟良善的價值推廣到全世界我也注意到對岸
# 最近在對聯合國視訊演說中公開表示中國永遠不稱霸不擴張不謀求勢力範圍窄區域國家來自於全世界都在擔憂中國擴張霸權的詞
# 希望這是一個真正改變的開始尤其在全球高度關注定太極兩岸局勢變化的重要時刻北京如果能夠正視臺灣的聲音改變處理兩岸關係的態度看臺灣共同促成
# 安德和價跟和平對話相信一定可以化解區域的緊張局勢面對兩岸關係我們不會冒進也會堅守原則維持兩岸關係的穩定是兩岸共同的利益
# 沒有決心為此兩岸的穩定但這不是臺灣可以單方面承擔的而是雙方共同的責任現階段兩岸當務之急是本於相互尊重單易理解的態度共同討論和平相處之道共存之法
# 只要北京當局有心化解對立改善兩岸關係在符合對等尊嚴的原則下我們願意共同促成有意義的對話這就是臺灣人民的主張也是朝野政黨的共識
# 但時間我們可以明顯的感受臺灣人民在對外關係以及國家安全的議題上彼此的距離正在拉近臺灣人民都希望區域的和平繁榮能夠安定有序朝野政黨之間
# 也是如此相似最近在立法院長提出促進臺美關係的一樣獲得朝野黨團的支援無意義的通過還有六都手掌一次對外共同抗疫成功的真正的國際組織
# 臺灣的做法這些都是畫的海合作團結表達立場的表現我想通過這些例子呼籲並且請國內各個政黨一起洗手努力對內互相競爭立場
# 針鋒相對是民主制廠不過為了國家的生存發展為了為了民主自由的價值對外我們應該團結努力的手帶領國家度過挑戰
# 就如同過去71年來臺灣經歷的一切困境我念出我們的堅韌挑戰激發我們的志氣異常的情景劇出臺灣人民團結的意思跟我們繼續前進的勇氣
# 疫情防線發展經濟戰略穩定區域區形式捍衛臺灣的安全為的是什麼就是要把一個壯大的國家有給臺灣的下一代今年的金曲獎
# 可以看到的年輕是在蓬勃的創造力和生命力他們用各種曲風志性的唱出自己的母語呈現出對各種議題的價值觀尤其是聽到該讓母親的舌頭這張專輯獲得了年
# 專輯獎的大獎這些年輕的創作者雖然風格各自不同但都能夠在舞臺上發光發亮也為臺灣的多元文化做出最好的詮釋自身體這一切的就是我們
# 民主自由的環境我們現在打拼的一切都是為了下一代讓世世代代的臺灣人可以在創作上展現自信也能對土地的文化和價值感到光榮並且容
# 走向世界在中華民國國慶的這一天我們也一起許下願望願20年後的臺灣人回想2020年的時候會想起正是在這一年因為
# 在時代中把握機遇在變局中勇敢的前進客戶的挑戰多的枷鎖讓他們有真正以自己的意志選擇未來的機會從現在起

# %% [markdown]
# # General Audio Features Explorations

# %%
import librosa
import librosa.display

# %% [markdown]
# ## Amplitude

# %%
y, r = librosa.load(youtube_wav_fname, mono=False)

fig, ax = plt.subplots(figsize=(15, 3))
img = librosa.display.waveshow(y, sr=r, ax=ax)

ax.set(title='Envelope view, stereo')
ax.label_outer()

plt.show()

# %% [markdown]
# ## Frequency

# %%
# Load audio file to Librosa
y, r = librosa.load(youtube_wav_fname)

# Converts data into short term Fourier transform. 
# STFT converts signals such that we can know the amplitude of the given frequency at a given time
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)

# Display spectogram
fig, ax = plt.subplots(figsize=(15, 3))
img = librosa.display.specshow(D, y_axis='linear', x_axis='time', sr=r)
ax.set(title='Linear-frequency power spectrogram')
ax.label_outer()

plt.colorbar()

# %%
fig, ax = plt.subplots(figsize=(15, 3))
img = librosa.display.specshow(D, y_axis='log', x_axis='time', sr=r)
ax.set(title='Logarithmic-frequency power spectrogram')
ax.label_outer()

plt.colorbar()
